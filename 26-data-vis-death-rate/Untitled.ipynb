# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("D:/DATA/aitpune/college study thingy/dsbdal/prac_exam_questions/26-data-vis-death-rate/accident_prediction_india.csv")

df.head()
# Out:
#           State Name City Name  Year    Month Day of Week Time of Day  \
# 0  Jammu and Kashmir   Unknown  2021      May      Monday        1:46
# 1      Uttar Pradesh   Lucknow  2018  January   Wednesday       21:30
# 2       Chhattisgarh   Unknown  2023      May   Wednesday        5:37
# 3      Uttar Pradesh   Lucknow  2020     June    Saturday        0:31
# 4             Sikkim   Unknown  2021   August    Thursday       11:21
#
#   Accident Severity  Number of Vehicles Involved Vehicle Type Involved  \
# 0           Serious                            5                 Cycle
# 1             Minor                            5                 Truck
# 2             Minor                            5            Pedestrian
# 3             Minor                            3                   Bus
# 4             Minor                            5                 Cycle
#
#    Number of Casualties  ...         Road Type      Road Condition  \
# ...

# %%
# 1. Line Plot → Year-wise Casualties
yearly_deaths = df.groupby("Year")["Number of Casualties"].sum()

plt.figure(figsize=(8,5))

plt.plot(yearly_deaths.index,
         yearly_deaths.values)

plt.title("Year-wise Death Count")
plt.xlabel("Year")
plt.ylabel("Number of Casualties")

plt.show()

# %%
# 2. Histogram → Distribution of Casualties
plt.figure(figsize=(8,5))

plt.hist(df["Number of Casualties"], bins=20)

plt.title("Distribution of Casualties")
plt.xlabel("Number of Casualties")
plt.ylabel("Frequency")

plt.show()

# %%
# 3. Count Plot → Accident Severity
plt.figure(figsize=(8,5))

sns.countplot(x="Accident Severity", data=df)

plt.title("Accident Severity Distribution")

plt.show()

# %%
max_year = yearly_deaths.idxmax()
max_value = yearly_deaths.max()

print("\nYear with Maximum Accidents:", max_year)
print("Maximum Number of Casualties:", max_value)
# Out:
# Year with Maximum Accidents: 2022
# Maximum Number of Casualties: 2780

# %%
state_deaths = df.groupby("State Name")["Number of Casualties"].sum()

# Sort descending
state_deaths = state_deaths.sort_values(ascending=False)

plt.figure(figsize=(12,6))

sns.barplot(
    x=state_deaths.index[:10],
    y=state_deaths.values[:10]
)

plt.title("Top 10 States by Death Count")
plt.xlabel("State")
plt.ylabel("Number of Casualties")

plt.xticks(rotation=45)

plt.show()
